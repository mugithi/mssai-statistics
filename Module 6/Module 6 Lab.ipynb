# %% [markdown]
# # Module 6 Lab

# %% [markdown]
# ## Generalized Linear Models

# %%
# Load necessary libraries
import pandas as pd # for data science
import numpy as np  # linear algebra library
import matplotlib.pyplot as plt # plotting library
import seaborn as sns # additional plotting library

# %% [markdown]
# ### Generating Our DataFrame

# %% [markdown]
# To begin this lab, we are going to formulate a randomized dataset with *n*=100 observations. Let's suppose we have a class of 100 students who have taken three exams.

# %%
def rand_df(x, y, state): 
    np.random.seed(state) # set seed for reproducibility
    # assign variable to a dataframe through the number 100
    val = pd.DataFrame(np.random.randint(x, y, size=100))
    val = val.round(decimals=0).astype(int) # no decimals, integers
    return val

# %%
df1 = rand_df(0, 100, 42) # exam 1
df2 = rand_df(0, 100, 23) # exam 2
df3 = rand_df(0, 100, 80) # exam 3
df4 = rand_df(0, 20, 36) # study hours

# %%
dfs = [df1, df2, df3, df4]
df5 = pd.concat(dfs, join='outer', axis=1)
df5.columns = ['Exam 1', 'Exam 2', 'Exam 3', 'Study_Hours']
df5['Final_Grade'] = df5[['Exam 1', 'Exam 2', 'Exam 3']].mean(axis=1)
# no decimals, integers
df5['Final_Grade'] = df5['Final_Grade'].round(decimals=0).astype(int) 
df5
# Out:
#     Exam 1  Exam 2  Exam 3  Study_Hours  Final_Grade
# 0       51      83      47            5           60
# 1       92      40      60            2           64
# 2       14      73      38            8           42
# 3       71      54      83            1           69
# 4       60      31      10           12           34
# ..     ...     ...     ...          ...          ...
# 95      84      81      82           15           82
# 96      79      32      95            7           69
# 97      81      53      80           11           71
# 98      52      35      77            6           55
# 99      23      23      44            2           30
#
# [100 rows x 5 columns]

# %% [markdown]
# ## Basic Scatterplots

# %%
x = df5['Exam 1'] 
y = df5['Final_Grade']
plt.title('Final Grade vs. Exam 1')
plt.xlabel('Exam 1')       
plt.ylabel('Final Grade')           

# create best-fit line based on slope-intercept form
m, b = np.polyfit(x, y, 1)
plt.scatter(x, y) 
plt.plot(x, m*x+b, color = 'red')

# correlation coefficient 
corr = round(np.corrcoef(x, y)[0,1],2)
plt.title('Final Grade vs. Exam 1;' ' $\mathit{r}$ = ' + "{:.2f}".format(corr))
plt.show()

# %%
x = df5['Exam 2'] 
y = df5['Final_Grade']
plt.title('Exam 2 vs. Final Grade')
plt.xlabel('Exam 2')       
plt.ylabel('Final Grade')           

# create best-fit line based on slope-intercept form
m, b = np.polyfit(x, y, 1)
plt.scatter(x, y) 
plt.plot(x, m*x+b, color = 'red')
corr = round(np.corrcoef(x, y)[0,1],2)
plt.title('Exam 2 vs. Final Grade;' ' $\mathit{r}$ = ' + "{:.2f}".format(corr))
plt.show()

# %%
x = df5['Exam 3'] 
y = df5['Final_Grade']
plt.title('Exam 3 vs. Final Grade')
plt.xlabel('Exam 3')       
plt.ylabel('Final Grade')           

# create best-fit line based on slope-intercept form
m, b = np.polyfit(x, y, 1)
plt.scatter(x, y) 
plt.plot(x, m*x+b, color = 'red')
corr = round(np.corrcoef(x, y)[0,1],2)
plt.title('Exam 3 vs. Final Grade;' ' $\mathit{r}$ = ' + "{:.2f}".format(corr))
plt.show()

# %%
x = df5['Study_Hours'] 
y = df5['Final_Grade']
plt.title('Exam 3 vs. Final Grade')
plt.xlabel('Study_Hours')       
plt.ylabel('Final Grade')           

# create best-fit line based on slope-intercept form
m, b = np.polyfit(x, y, 1)
plt.scatter(x, y) 
plt.plot(x, m*x+b, color = 'red')
corr = round(np.corrcoef(x, y)[0,1],2)
plt.title('Study Hours vs. Final Grade;' ' $\mathit{r}$ = ' + 
          "{:.2f}".format(corr))
plt.show()

# %% [markdown]
# ### Scatterplots in a Loop

# %%
y_col = 'Final_Grade'
x_columns = ['Exam 1', 'Exam 2', 'Exam 3', 'Study_Hours']

for x_col in x_columns:
    figure = plt.figure()
    ax = plt.gca()
    m, b = np.polyfit(df5[x_col], df5[y_col], 1)
    plt.plot(df5[x_col], m*df5[x_col]+b, color = 'red')
    ax.scatter(df5[x_col], df5[y_col])
    ax.set_xlabel(x_col)
    ax.set_ylabel(y_col)
    corr = round(np.corrcoef(df5[x_col], df5[y_col])[0,1],2) 
    ax.set_title('{} vs. {};'.format(x_col, y_col) 
                 + ' $\mathit{r}$ = ' 
                 + '{:.2f}'.format(corr))
    plt.show()

# %% [markdown]
# ## Linear Regression

# %% [markdown]
# $y = b_{0} + b_{1}x_{1} + b_{2}x_{2} + ... + b_{n}x_{n} + \varepsilon$

# %% [markdown]
# ### Simple Linear Regression

# %% [markdown]
# * Univariate analysis
# $y = b_{0} + b_{1}x_{1} + \varepsilon$

# %%
# univariate analysis
X1 = df5['Exam 1']
y = df5['Final_Grade']

import statsmodels.api as sm # use stats models for basic linear regression
X1 = sm.add_constant(X1) # adds constant to the model
model = sm.OLS(y, X1).fit()
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            Final_Grade   R-squared:                       0.388
# Model:                            OLS   Adj. R-squared:                  0.382
# Method:                 Least Squares   F-statistic:                     62.25
# Date:                Sun, 19 Feb 2023   Prob (F-statistic):           4.35e-12
# Time:                        03:38:51   Log-Likelihood:                -399.61
# No. Observations:                 100   AIC:                             803.2
# Df Residuals:                      98   BIC:                             808.4
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         32.0540      2.652     12.087      0.000      26.791      37.317
# Exam 1         0.3583      0.045      7.890      0.000       0.268       0.448
# ==============================================================================
# Omnibus:                        5.483   Durbin-Watson:                   2.076
# Prob(Omnibus):                  0.064   Jarque-Bera (JB):                3.430
# Skew:                          -0.272   Prob(JB):                        0.180
# Kurtosis:                       2.274   Cond. No.                         117.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %% [markdown]
# $y = 32.05 + 0.36 \text{ (Exam 1)} + \varepsilon$

# %% [markdown]
# ### Multiple Linear Regression

# %% [markdown]
# **For the following exercises, we will work with the `Facebook metrics` dataset $^1$**
#
# https://archive.ics.uci.edu/ml/datasets/Facebook+metrics

# %%
import statsmodels.api as sm
facebook = pd.read_csv('dataset_Facebook.csv', sep=';')

# %%
facebook.head()
# Out:
#    Page total likes    Type  Category  Post Month  Post Weekday  Post Hour  \
# 0            139441   Photo         2          12             4          3
# 1            139441  Status         2          12             3         10
# 2            139441   Photo         3          12             3          3
# 3            139441   Photo         2          12             2         10
# 4            139441   Photo         2          12             2          3
#
#    Paid  Lifetime Post Total Reach  Lifetime Post Total Impressions  \
# 0   0.0                       2752                             5091
# 1   0.0                      10460                            19057
# 2   0.0                       2413                             4373
# 3   1.0                      50128                            87991
# 4   0.0                       7244                            13594
#
#    Lifetime Engaged Users  Lifetime Post Consumers  \
# 0                     178                      109
# 1                    1457                     1361
# 2                     177                      113
# 3                    2211                      790
# 4                     671                      410
#
#    Lifetime Post Consumptions  \
# 0                         159
# 1                        1674
# 2                         154
# 3                        1119
# 4                         580
#
#    Lifetime Post Impressions by people who have liked your Page  \
# 0                                               3078
# 1                                              11710
# 2                                               2812
# 3                                              61027
# 4                                               6228
#
#    Lifetime Post reach by people who like your Page  \
# 0                                              1640
# 1                                              6112
# 2                                              1503
# 3                                             32048
# 4                                              3200
#
#    Lifetime People who have liked your Page and engaged with your post  \
# 0                                                119
# 1                                               1108
# 2                                                132
# 3                                               1386
# 4                                                396
#
#    comment    like  share  Total Interactions
# 0        4    79.0   17.0                 100
# 1        5   130.0   29.0                 164
# 2        0    66.0   14.0                  80
# 3       58  1572.0  147.0                1777
# 4       19   325.0   49.0                 393

# %% [markdown]
# **Let's leverage the data to run a linear regression model that predicts the `Total Interactions` (dependent variable ) based on the other columns of data (independent variables $x_1, x_2, x_3, \cdots x_{n}$).**

# %%
# we cannot have non-encoded categorical features in a linear regression model
# since the model only relies on numerical data

facebook['Type'].value_counts() # let's inspect the 'Type' column
# Out:
# Photo     426
# Status     45
# Link       22
# Video       7
# Name: Type, dtype: int64

# %%
facebook_enc = pd.get_dummies(facebook, columns = ['Type'])
facebook_enc.head()
# Out:
#    Page total likes  Category  Post Month  Post Weekday  Post Hour  Paid  \
# 0            139441         2          12             4          3   0.0
# 1            139441         2          12             3         10   0.0
# 2            139441         3          12             3          3   0.0
# 3            139441         2          12             2         10   1.0
# 4            139441         2          12             2          3   0.0
#
#    Lifetime Post Total Reach  Lifetime Post Total Impressions  \
# 0                       2752                             5091
# 1                      10460                            19057
# 2                       2413                             4373
# 3                      50128                            87991
# 4                       7244                            13594
#
#    Lifetime Engaged Users  Lifetime Post Consumers  ...  \
# 0                     178                      109  ...
# 1                    1457                     1361  ...
# 2                     177                      113  ...
# 3                    2211                      790  ...
# 4                     671                      410  ...
#
#    Lifetime Post reach by people who like your Page  \
# 0                                              1640
# 1                                              6112
# 2                                              1503
# 3                                             32048
# 4                                              3200
#
#    Lifetime People who have liked your Page and engaged with your post  \
# 0                                                119
# 1                                               1108
# 2                                                132
# 3                                               1386
# 4                                                396
#
#    comment    like  share  Total Interactions  Type_Link  Type_Photo  \
# 0        4    79.0   17.0                 100          0           1
# 1        5   130.0   29.0                 164          0           0
# 2        0    66.0   14.0                  80          0           1
# 3       58  1572.0  147.0                1777          0           1
# 4       19   325.0   49.0                 393          0           1
#
#    Type_Status  Type_Video
# 0            0           0
# 1            1           0
# 2            0           0
# 3            0           0
# 4            0           0
#
# [5 rows x 22 columns]

# %%
facebook_enc.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 22 columns):
#  #   Column                                                               Non-Null Count  Dtype
# ---  ------                                                               --------------  -----
#  0   Page total likes                                                     500 non-null    int64
#  1   Category                                                             500 non-null    int64
#  2   Post Month                                                           500 non-null    int64
#  3   Post Weekday                                                         500 non-null    int64
#  4   Post Hour                                                            500 non-null    int64
#  5   Paid                                                                 499 non-null    float64
#  6   Lifetime Post Total Reach                                            500 non-null    int64
#  7   Lifetime Post Total Impressions                                      500 non-null    int64
#  8   Lifetime Engaged Users                                               500 non-null    int64
#  9   Lifetime Post Consumers                                              500 non-null    int64
#  10  Lifetime Post Consumptions                                           500 non-null    int64
#  11  Lifetime Post Impressions by people who have liked your Page         500 non-null    int64
#  12  Lifetime Post reach by people who like your Page                     500 non-null    int64
#  13  Lifetime People who have liked your Page and engaged with your post  500 non-null    int64
#  14  comment                                                              500 non-null    int64
#  15  like                                                                 499 non-null    float64
#  16  share                                                                496 non-null    float64
#  17  Total Interactions                                                   500 non-null    int64
#  18  Type_Link                                                            500 non-null    uint8
#  19  Type_Photo                                                           500 non-null    uint8
#  20  Type_Status                                                          500 non-null    uint8
#  21  Type_Video                                                           500 non-null    uint8
# dtypes: float64(3), int64(15), uint8(4)
# memory usage: 72.4 KB

# %%
nulls = pd.DataFrame(facebook_enc.isnull().sum(), columns=['Nulls'])
nulls = nulls[nulls['Nulls']>0]
nulls
# Out:
#        Nulls
# Paid       1
# like       1
# share      4

# %%
# impute the missing values with mean since few of them
facebook_enc['Paid'].fillna((facebook_enc)['Paid'].mean(), inplace=True)
facebook_enc['like'].fillna((facebook_enc)['like'].mean(), inplace=True)
facebook_enc['share'].fillna((facebook_enc)['share'].mean(), inplace=True)

# %%
# assign independent variables, dependent variable, respectively
x = facebook_enc.loc[:, facebook_enc.columns != 'Total Interactions']
# define the target
y = pd.DataFrame(facebook_enc['Total Interactions'])

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(x, y, test_size=0.3, 
                                                    random_state=42)

# %%
X_train = sm.add_constant(X_train)
model = sm.OLS(y_train, X_train).fit()
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:     Total Interactions   R-squared:                       0.999
# Model:                            OLS   Adj. R-squared:                  0.999
# Method:                 Least Squares   F-statistic:                 2.654e+04
# Date:                Sun, 19 Feb 2023   Prob (F-statistic):               0.00
# Time:                        03:38:51   Log-Likelihood:                -1326.0
# No. Observations:                 350   AIC:                             2694.
# Df Residuals:                     329   BIC:                             2775.
# Df Model:                          20
# Covariance Type:            nonrobust
# =======================================================================================================================================
#                                                                           coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------------------------------------------------------
# const                                                                  -1.5203      8.759     -0.174      0.862     -18.752      15.711
# Page total likes                                                     2.712e-05      0.000      0.233      0.816      -0.000       0.000
# Category                                                                1.3363      0.824      1.622      0.106      -0.285       2.958
# Post Month                                                             -0.4031      0.587     -0.687      0.493      -1.558       0.751
# Post Weekday                                                           -0.3750      0.301     -1.245      0.214      -0.968       0.218
# Post Hour                                                              -0.0517      0.148     -0.348      0.728      -0.343       0.240
# Paid                                                                    0.7928      1.327      0.597      0.551      -1.818       3.404
# Lifetime Post Total Reach                                           -4.807e-05      0.000     -0.421      0.674      -0.000       0.000
# Lifetime Post Total Impressions                                      1.334e-05      4e-05      0.333      0.739   -6.54e-05    9.21e-05
# Lifetime Engaged Users                                                  0.0753      0.018      4.258      0.000       0.041       0.110
# Lifetime Post Consumers                                                -0.0759      0.018     -4.278      0.000      -0.111      -0.041
# Lifetime Post Consumptions                                              0.0005      0.001      0.821      0.412      -0.001       0.002
# Lifetime Post Impressions by people who have liked your Page        -1.361e-05   5.01e-05     -0.272      0.786      -0.000     8.5e-05
# Lifetime Post reach by people who like your Page                     4.804e-05      0.000      0.188      0.851      -0.000       0.001
# Lifetime People who have liked your Page and engaged with your post     0.0052      0.003      1.825      0.069      -0.000       0.011
# comment                                                                 1.1143      0.060     18.601      0.000       0.996       1.232
# like                                                                    0.9268      0.017     53.776      0.000       0.893       0.961
# share                                                                   1.0278      0.043     23.832      0.000       0.943       1.113
# Type_Link                                                               1.2289      3.235      0.380      0.704      -5.135       7.593
# Type_Photo                                                             -1.4262      2.724     -0.524      0.601      -6.784       3.932
# Type_Status                                                            -4.0528      3.691     -1.098      0.273     -11.315       3.209
# Type_Video                                                              2.7298      4.944      0.552      0.581      -6.996      12.456
# ==============================================================================
# Omnibus:                      761.887   Durbin-Watson:                   2.036
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):          1102497.103
# Skew:                         -15.702   Prob(JB):                         0.00
# Kurtosis:                     276.155   Cond. No.                     1.31e+20
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 3.47e-28. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
# """

# %% [markdown]
# ### Multiple Linear Regression with Scikit-Learn

# %%
from sklearn.linear_model import LinearRegression

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.3, 
                                                    random_state=42)

# %%
sk_model = LinearRegression()

# %%
sk_model.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
print('Model Coefficients:', sk_model.coef_)
print()
print('Intercept:', sk_model.intercept_)
coef = pd.DataFrame(sk_model.coef_.T, columns=['Coefficients'])
cols = pd.DataFrame(x.columns, columns=['Columns'])
joined = pd.concat([cols['Columns'], coef['Coefficients']], axis=1)
joined
# Out:
# Model Coefficients: [[ 2.71182176e-05  1.33633125e+00 -4.03104713e-01 -3.75019769e-01
#   -5.16763645e-02  7.92816457e-01 -4.80744970e-05  1.33402853e-05
#    7.52920566e-02 -7.58996703e-02  5.23648411e-04 -1.36140539e-05
#    4.80422921e-05  5.24009820e-03  1.11434602e+00  9.26801735e-01
#    1.02779838e+00  1.60898568e+00 -1.04616705e+00 -3.67272850e+00
#    3.10990987e+00]]
#
# Intercept: [-1.90037734]
#                                               Columns  Coefficients
# 0                                    Page total likes      0.000027
# 1                                            Category      1.336331
# 2                                          Post Month     -0.403105
# 3                                        Post Weekday     -0.375020
# 4                                           Post Hour     -0.051676
# 5                                                Paid      0.792816
# 6                           Lifetime Post Total Reach     -0.000048
# 7                     Lifetime Post Total Impressions      0.000013
# 8                              Lifetime Engaged Users      0.075292
# 9                             Lifetime Post Consumers     -0.075900
# 10                         Lifetime Post Consumptions      0.000524
# 11  Lifetime Post Impressions by people who have l...     -0.000014
# 12   Lifetime Post reach by people who like your Page      0.000048
# 13  Lifetime People who have liked your Page and e...      0.005240
# 14                                            comment      1.114346
# 15                                               like      0.926802
# 16                                              share      1.027798
# 17                                          Type_Link      1.608986
# 18                                         Type_Photo     -1.046167
# 19                                        Type_Status     -3.672729
# 20                                         Type_Video      3.109910

# %%
predictions = sk_model.predict(x_test)
pd.DataFrame(predictions, columns=['Predictions'])
# Out:
#      Predictions
# 0     105.012872
# 1     233.018082
# 2      74.990626
# 3      68.081324
# 4      70.535298
# ..           ...
# 145   100.025851
# 146    93.686734
# 147    83.969836
# 148   286.870406
# 149     3.829755
#
# [150 rows x 1 columns]

# %%
plt.scatter(y_test, predictions)
plt.title('Predictions vs. Actual')
plt.xlabel('Actual')
plt.ylabel('Predictions')
plt.show()

# %% [markdown]
# ----------------
#
#
# $^{1}$ Moro, S., Rita, P., & Vala B. (2016). Predicting social media performance metrics and evaluation
#    of the impact on brand building: A data mining approach. *Journal of Business Research, Elsevier,* 3341–3351.
#    https://doi.org/10.1016/j.jbusres.2016.02.010
